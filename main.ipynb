# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. 
# This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data

# %%
# 查看工作区文件, 该目录下的变更将会持久保存. 请及时清理不必要的文件, 避免加载过慢.
# View personal work directory. 
# All changes under this directory will be kept even after reset. 
# Please clean unnecessary files in time to speed up environment loading. 
# !ls /home/aistudio/work

# %%
# 如果需要进行持久化安装, 需要使用持久化路径, 如下方代码示例:
# If a persistence installation is required, 
# you need to use the persistence path as the following: 
# !mkdir /home/aistudio/external-libraries
# !pip install beautifulsoup4 -t /home/aistudio/external-libraries

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可: 
# Also add the following code, 
# so that every time the environment (kernel) starts, 
# just run the following code: 
import sys 
sys.path.append('/home/aistudio/external-libraries')

# %% [markdown]
# # 0.导入必要的包

# %%
 # -*- coding:utf-8 -*-
import os 
import pickle
import random
import argparse
import platform
import numpy as np
from glob import glob
from tqdm import tqdm
import pandas as pd
from sklearn.utils import shuffle
from matplotlib import pyplot as plt
import scipy

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.

# %% [markdown]
# # 1.加载数据，训练集和测试集划分

# %%
 # 加载训练集的pkl文件，划分训练集与验证集
ind_pkl_files = []#存放标签为0的文件
ood_pkl_files = []#存放标签为1的文件
data_path="Train"#存放数据的路径
pkl_files = glob(data_path+'/*.pkl')
for each_path in tqdm(pkl_files):
    pic = open(each_path,'rb')
    this_pkl_file= pickle.load(pic)#下载pkl文件
    if this_pkl_file[1]['label'] == '00':
        ind_pkl_files.append(each_path)
    else:
        ood_pkl_files.append(each_path)
random.seed(2022)
# 排序并打乱存放车辆序号的集合
random.shuffle(ind_pkl_files)
random.shuffle(ood_pkl_files)
# 3/4的正样本和全部的负样本作为训练集，1/4的正样本和1/4的负样本作为训练集
#train_pkl_files = [ ind_pkl_files[j] for j in range(len(ind_pkl_files)//4,len(ind_pkl_files))] + [ ood_pkl_files[i] for i in range(len(ood_pkl_files))]
train_pkl_files = [ ind_pkl_files[j] for j in range(len(ind_pkl_files)//4,len(ind_pkl_files))] + [ ood_pkl_files[i] for i in range(len(ood_pkl_files)//4,len(ood_pkl_files))]
test_pkl_files=[ind_pkl_files[i] for i in range(len(ind_pkl_files)//4)] + [ood_pkl_files[i] for i in range(len(ood_pkl_files)//4)]
# Out:
# 100%|██████████| 28389/28389 [00:07<00:00, 3963.35it/s]

# %% [markdown]
# # 2.定义读取数据集及归一化函数

# %%
def  load_data(pkl_list,label=True):
    '''
    输入pkl的列表，进行文件加载
    label=True用来加载训练集
    label=False用来加载真正的测试集，真正的测试集无标签
    '''
    X = []
    y = []
    

    for  each_pkl in pkl_list:
        pic = open(each_pkl,'rb')
        item= pickle.load(pic)#下载pkl文件
        # 此处选取的是每个滑窗的最后一条数据，仅供参考，可以选择其他的方法，比如均值或者其他处理时序数据的网络
        # 此处选取了前7个特征，可以需求选取特征数量
        feature = item[0][:,0:7][-1]
        #feature = item[0][:,0:8][-1]
        #feature = item[0][:,0:7].mean(axis=0)
        #feature = np.append(item[0][:,0:7][-1],(item[0][:,3][-1] - item[0][:,4][-1])) #加max_single_volt - min_single_volt 一列为特征
        feature=np.append(feature,item[1]["mileage"])
        X.append(feature)
        if label:
            y.append(int(item[1]['label'][0]))
    X = np.vstack(X)
    if label:
        y = np.vstack(y)
    return X, y
    
def normalization(data,_mean,_std): 
    """
    归一化数据
    """
    data = (data - _mean) / (_std + 1e-4)
    return data

# %% [markdown]
# # 3.加载并归一化训练数据和验证数据

# %%
 # 加载并归一化训练数据和验证数据
X_train,y_train=load_data(train_pkl_files)
# 进行随机打乱，这里random_state指定为固定值，则打乱结果相同
X_train,y_train = shuffle(X_train,y_train,random_state=40)
X_test,y_test=load_data(test_pkl_files)
_mean = np.mean(X_train, axis=0)
_std = np.std(X_train, axis=0)
X_train = normalization(X_train,_mean,_std)
X_test = normalization(X_test,_mean,_std)

test1_files = glob("Test_A"+'/*.pkl')
X_val,_=load_data(test1_files,label=False)
X_val = normalization(X_val,_mean,_std)

# %% [markdown]
# # 4.定义网络结构

# %%
import paddle
from paddle import nn


def _make_nn_module(module_type, *args):
    if isinstance(module_type, str):
        if module_type == 'ReGLU':
            return ReGLU()
        elif module_type == 'GEGLU':
            return GEGLU()
        else:
            try:
                cls = getattr(nn, module_type)
            except AttributeError as err:
                raise ValueError(
                    f'Failed to construct the module {module_type} with the arguments {args}'
                ) from err
            return cls(*args)
    else:
        return module_type(*args)

class ResNet(nn.Layer):
    """The ResNet model used in [gorishniy2021revisiting].
    The following scheme describes the architecture:
    .. code-block:: text
        ResNet: (in) -> Linear -> Block -> ... -> Block -> Head -> (out)
                 |-> Norm -> Linear -> Activation -> Dropout -> Linear -> Dropout ->|
                 |                                                                  |
         Block: (in) ------------------------------------------------------------> Add -> (out)
          Head: (in) -> Norm -> Activation -> Linear -> (out)
    Examples:
        .. testcode::
            x = torch.randn(4, 2)
            module = ResNet.make_baseline(
                d_in=x.shape[1],
                n_blocks=2,
                d_main=3,
                d_hidden=4,
                dropout_first=0.25,
                dropout_second=0.0,
                d_out=1
            )
            assert module(x).shape == (len(x), 1)
    References:
        * [gorishniy2021revisiting] Yury Gorishniy, Ivan Rubachev, Valentin Khrulkov, Artem Babenko, "Revisiting Deep Learning Models for Tabular Data", 2021
    """
    class Block(nn.Layer):
        """The main building block of `ResNet`."""

        def __init__(
            self,
            *,
            d_main,
            d_hidden,
            bias_first,
            bias_second,
            dropout_first,
            dropout_second,
            normalization,
            activation,
            skip_connection,
        ):
            super().__init__()
            self.normalization = _make_nn_module(normalization, d_main)
            self.linear_first = nn.Linear(d_main, d_hidden, bias_first)
            self.activation = _make_nn_module(activation)
            self.dropout_first = nn.Dropout(dropout_first)
            self.linear_second = nn.Linear(d_hidden, d_main, bias_second)
            self.dropout_second = nn.Dropout(dropout_second)
            self.skip_connection = skip_connection

        def forward(self, x):
            x_input = x
            x = self.normalization(x)
            x = self.linear_first(x)
            x = self.activation(x)
            x = self.dropout_first(x)
            x = self.linear_second(x)
            x = self.dropout_second(x)
            if self.skip_connection:
                x = x_input + x
            return x

    class Head(nn.Layer):
        """The final module of `ResNet`."""

        def __init__(
            self,
            *,
            d_in,
            d_out,
            bias,
            normalization,
            activation,
        ):
            super().__init__()
            self.normalization = _make_nn_module(normalization, d_in)
            self.activation = _make_nn_module(activation)
            self.linear = nn.Linear(d_in, d_out, bias)

        def forward(self, x):
            if self.normalization is not None:
                x = self.normalization(x)
            x = self.activation(x)
            x = self.linear(x)
            return x

    def __init__(
        self,
        *,
        d_in,
        n_blocks,
        d_main,
        d_hidden,
        dropout_first,
        dropout_second,
        normalization,
        activation,
        d_out: int,
    ) -> None:
        """
        Note:
            `make_baseline` is the recommended constructor.
        """
        super().__init__()

        self.first_layer = nn.Linear(d_in, d_main)
        if d_main is None:
            d_main = d_in
        self.blocks = nn.Sequential(
            *[
                ResNet.Block(
                    d_main=d_main,
                    d_hidden=d_hidden,
                    bias_first=True,
                    bias_second=True,
                    dropout_first=dropout_first,
                    dropout_second=dropout_second,
                    normalization=normalization,
                    activation=activation,
                    skip_connection=True,
                )
                for _ in range(n_blocks)
            ]
        )
        self.head = ResNet.Head(
            d_in=d_main,
            d_out=d_out,
            bias=True,
            normalization=normalization,
            activation=activation,
        )

    @classmethod
    def make_baseline(
        cls,
        *,
        d_in,
        n_blocks,
        d_main,
        d_hidden,
        dropout_first,
        dropout_second,
        d_out,
    ) -> 'ResNet':
        """Create a "baseline" `ResNet`.
        This variation of ResNet was used in [gorishniy2021revisiting]. Features:
        * :code:`Activation` = :code:`ReLU`
        * :code:`Norm` = :code:`BatchNorm1d`
        Args:
            d_in: the input size
            n_blocks: the number of Blocks
            d_main: the input size (or, equivalently, the output size) of each Block
            d_hidden: the output size of the first linear layer in each Block
            dropout_first: the dropout rate of the first dropout layer in each Block.
            dropout_second: the dropout rate of the second dropout layer in each Block.
        References:
            * [gorishniy2021revisiting] Yury Gorishniy, Ivan Rubachev, Valentin Khrulkov, Artem Babenko, "Revisiting Deep Learning Models for Tabular Data", 2021
        """
        return cls(
            d_in=d_in,
            n_blocks=n_blocks,
            d_main=d_main,
            d_hidden=d_hidden,
            dropout_first=dropout_first,
            dropout_second=dropout_second,
            normalization='BatchNorm1D',
            activation='ReLU',
            d_out=d_out,
        )

    def forward(self, x):
        x = self.first_layer(x)
        x = self.blocks(x)
        x = self.head(x)
        return x

# %% [markdown]
# ### 5.定义dataloader,loss,验证方法

# %%
class PyODDataset(paddle.io.Dataset):

    def __init__(self, X, y):
        super(PyODDataset, self).__init__()
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        sample = self.X[idx, :]
        label = self.y[idx,:]

        return paddle.to_tensor(sample,dtype="float32"), paddle.to_tensor(label,dtype="float32")

class Loss(paddle.nn.Layer):

   def forward(self, inputs, labels):
       #return paddle.nn.functional.mse_loss(input=input.squeeze(), label=label.squeeze())
       #return  paddle.nn.loss.CrossEntropyLoss(inputs.squeeze(), labels.squeeze())
       return  paddle.nn.functional.binary_cross_entropy_with_logits(inputs.squeeze(), labels.squeeze())
       #return  paddle.nn.functional.sigmoid_focal_loss(inputs.squeeze(), labels.squeeze())



def evaluate(X_test, y_test, pos_label=1):
        y_scores = scipy.special.expit(model(paddle.to_tensor(X_test,dtype="float32")).numpy())
        aucroc = roc_auc_score(y_true=y_test, y_score=y_scores)
        aucpr = average_precision_score(y_true=y_test, y_score=y_scores, pos_label=1)
        metric = {'aucroc': aucroc, 'aucpr': aucpr}
        return y_scores,metric['aucpr']

# %% [markdown]
# ### 6.训练

# %%
from sklearn.metrics import roc_auc_score, average_precision_score
import warnings
warnings.filterwarnings("ignore")
model = ResNet.make_baseline(
                d_in=8,
                d_main=128,
                d_hidden=256,
                dropout_first=0.25,
                dropout_second=0.0,
                n_blocks=2,
                d_out=1,
            )
model.train()
train_dataset=PyODDataset(X_train,y_train) # 正负样例{0: 17802, 1: 3491}
#train_dataset=PyODDataset(X_res,y_res)   # 正负样例1:1
train_loader = paddle.io.DataLoader(train_dataset, places=paddle.CPUPlace(), batch_size=256, shuffle=True, num_workers=0)
test_dataset=PyODDataset(X_test,y_test) 
test_loader = paddle.io.DataLoader(test_dataset, places=paddle.CPUPlace(), batch_size=8, shuffle=False, num_workers=0)
losspsnr = Loss()
max_epoch=532
#scheduler = paddle.optimizer.lr.CosineAnnealingDecay(learning_rate=0.001, T_max=max_epoch)
#opt = paddle.optimizer.AdamW(learning_rate=scheduler, parameters=model.parameters())  
opt = paddle.optimizer.AdamW(learning_rate=0.001, parameters=model.parameters())  
now_step=0
import time
train_loss = []
val_loss = []
for epoch in range(max_epoch):
    epoch_loss = []
    val_epoch_loss = []
    model.train()
    for step, data in enumerate(train_loader):
        now_step+=1
        img, label = data
        pre = model(img)
        # print(pre)
        # print(label)
        loss = losspsnr(pre,label)
        epoch_loss.append(loss.item())
        loss.backward()
        opt.step()
        opt.clear_gradients()
    loss_ep = sum(epoch_loss)/len(epoch_loss)
    train_loss.append(loss_ep)
   
    #==========================每次进行完一个训练迭代，就去测试一把看看此时的效果==========================
    # 在测试集上检验效果
    model.eval()  # 将模型改为预测模式
    # 每次迭代都是处理一个小批量的数据，batch_size是1
    for step, data in enumerate(test_loader):
        img, label = data
        pre = model(img)
        loss1 = losspsnr(pre,label)
        val_loss.append(loss1.item())
    eval_loss = sum(val_loss)/len(val_loss)
    _, val_metric = evaluate(X_train, y_train)
    print(f'Epoch {epoch:03d} |loss is: {loss_ep:.4f} | Validation metric: {val_metric:.4f}')
# Out:
# Epoch 000 |loss is: 0.3277 | Validation metric: 0.8105
# Epoch 001 |loss is: 0.1961 | Validation metric: 0.8802
# Epoch 002 |loss is: 0.1678 | Validation metric: 0.8985
# Epoch 003 |loss is: 0.1456 | Validation metric: 0.9340
# Epoch 004 |loss is: 0.1255 | Validation metric: 0.9549
# Epoch 005 |loss is: 0.1125 | Validation metric: 0.9744
# Epoch 006 |loss is: 0.1017 | Validation metric: 0.9766
# Epoch 007 |loss is: 0.0952 | Validation metric: 0.9789
# Epoch 008 |loss is: 0.0955 | Validation metric: 0.9829
# Epoch 009 |loss is: 0.0890 | Validation metric: 0.9697
# Epoch 010 |loss is: 0.0914 | Validation metric: 0.9789
# Epoch 011 |loss is: 0.0861 | Validation metric: 0.9778
# Epoch 012 |loss is: 0.0811 | Validation metric: 0.9804
# Epoch 013 |loss is: 0.0795 | Validation metric: 0.9860
# Epoch 014 |loss is: 0.0846 | Validation metric: 0.9836
# Epoch 015 |loss is: 0.0792 | Validation metric: 0.9895
# Epoch 016 |loss is: 0.0736 | Validation metric: 0.9889
# Epoch 017 |loss is: 0.0730 | Validation metric: 0.9827
# Epoch 018 |loss is: 0.0723 | Validation metric: 0.9845
# Epoch 019 |loss is: 0.0692 | Validation metric: 0.9870
# Epoch 020 |loss is: 0.0652 | Validation metric: 0.9909
# Epoch 021 |loss is: 0.0695 | Validation metric: 0.9883
# Epoch 022 |loss is: 0.0676 | Validation metric: 0.9878
# Epoch 023 |loss is: 0.0666 | Validation metric: 0.9911
# Epoch 024 |loss is: 0.0652 | Validation metric: 0.9874
# Epoch 025 |loss is: 0.0667 | Validation metric: 0.9887
# Epoch 026 |loss is: 0.0641 | Validation metric: 0.9867
# Epoch 027 |loss is: 0.0616 | Validation metric: 0.9919
# Epoch 028 |loss is: 0.0703 | Validation metric: 0.9886
# Epoch 029 |loss is: 0.0632 | Validation metric: 0.9909
# Epoch 030 |loss is: 0.0613 | Validation metric: 0.9923
# Epoch 031 |loss is: 0.0629 | Validation metric: 0.9874
# Epoch 032 |loss is: 0.0566 | Validation metric: 0.9884
# Epoch 033 |loss is: 0.0632 | Validation metric: 0.9934
# Epoch 034 |loss is: 0.0642 | Validation metric: 0.9946
# Epoch 035 |loss is: 0.0587 | Validation metric: 0.9925
# Epoch 036 |loss is: 0.0563 | Validation metric: 0.9915
# Epoch 037 |loss is: 0.0582 | Validation metric: 0.9914
# Epoch 038 |loss is: 0.0553 | Validation metric: 0.9930
# Epoch 039 |loss is: 0.0512 | Validation metric: 0.9947
# Epoch 040 |loss is: 0.0497 | Validation metric: 0.9894
# Epoch 041 |loss is: 0.0496 | Validation metric: 0.9925
# Epoch 042 |loss is: 0.0529 | Validation metric: 0.9933
# Epoch 043 |loss is: 0.0522 | Validation metric: 0.9909
# Epoch 044 |loss is: 0.0516 | Validation metric: 0.9952
# Epoch 045 |loss is: 0.0484 | Validation metric: 0.9953
# Epoch 046 |loss is: 0.0499 | Validation metric: 0.9943
# Epoch 047 |loss is: 0.0523 | Validation metric: 0.9949
# Epoch 048 |loss is: 0.0585 | Validation metric: 0.9946
# Epoch 049 |loss is: 0.0554 | Validation metric: 0.9962
# Epoch 050 |loss is: 0.0507 | Validation metric: 0.9969
# Epoch 051 |loss is: 0.0469 | Validation metric: 0.9938
# Epoch 052 |loss is: 0.0504 | Validation metric: 0.9946
# Epoch 053 |loss is: 0.0470 | Validation metric: 0.9910
# Epoch 054 |loss is: 0.0533 | Validation metric: 0.9961
# Epoch 055 |loss is: 0.0486 | Validation metric: 0.9965
# Epoch 056 |loss is: 0.0493 | Validation metric: 0.9946
# Epoch 057 |loss is: 0.0490 | Validation metric: 0.9935
# Epoch 058 |loss is: 0.0482 | Validation metric: 0.9973
# Epoch 059 |loss is: 0.0447 | Validation metric: 0.9972
# Epoch 060 |loss is: 0.0382 | Validation metric: 0.9975
# Epoch 061 |loss is: 0.0423 | Validation metric: 0.9959
# Epoch 062 |loss is: 0.0453 | Validation metric: 0.9929
# Epoch 063 |loss is: 0.0470 | Validation metric: 0.9963
# Epoch 064 |loss is: 0.0439 | Validation metric: 0.9976
# Epoch 065 |loss is: 0.0451 | Validation metric: 0.9972
# Epoch 066 |loss is: 0.0465 | Validation metric: 0.9964
# Epoch 067 |loss is: 0.0457 | Validation metric: 0.9955
# Epoch 068 |loss is: 0.0398 | Validation metric: 0.9974
# Epoch 069 |loss is: 0.0473 | Validation metric: 0.9901
# Epoch 070 |loss is: 0.0414 | Validation metric: 0.9962
# Epoch 071 |loss is: 0.0440 | Validation metric: 0.9950
# Epoch 072 |loss is: 0.0462 | Validation metric: 0.9975
# Epoch 073 |loss is: 0.0427 | Validation metric: 0.9964
# Epoch 074 |loss is: 0.0541 | Validation metric: 0.9964
# Epoch 075 |loss is: 0.0702 | Validation metric: 0.9926
# Epoch 076 |loss is: 0.0418 | Validation metric: 0.9964
# Epoch 077 |loss is: 0.0372 | Validation metric: 0.9971
# Epoch 078 |loss is: 0.0369 | Validation metric: 0.9965
# Epoch 079 |loss is: 0.0407 | Validation metric: 0.9935
# Epoch 080 |loss is: 0.0409 | Validation metric: 0.9970
# Epoch 081 |loss is: 0.0363 | Validation metric: 0.9976
# Epoch 082 |loss is: 0.0397 | Validation metric: 0.9974
# Epoch 083 |loss is: 0.0410 | Validation metric: 0.9971
# Epoch 084 |loss is: 0.0422 | Validation metric: 0.9976
# Epoch 085 |loss is: 0.0437 | Validation metric: 0.9975
# Epoch 086 |loss is: 0.0361 | Validation metric: 0.9977
# Epoch 087 |loss is: 0.0401 | Validation metric: 0.9973
# Epoch 088 |loss is: 0.0389 | Validation metric: 0.9984
# Epoch 089 |loss is: 0.0356 | Validation metric: 0.9983
# Epoch 090 |loss is: 0.0414 | Validation metric: 0.9980
# Epoch 091 |loss is: 0.0381 | Validation metric: 0.9976
# Epoch 092 |loss is: 0.0416 | Validation metric: 0.9957
# Epoch 093 |loss is: 0.0476 | Validation metric: 0.9984
# Epoch 094 |loss is: 0.0364 | Validation metric: 0.9985
# Epoch 095 |loss is: 0.0404 | Validation metric: 0.9984
# Epoch 096 |loss is: 0.0395 | Validation metric: 0.9978
# Epoch 097 |loss is: 0.0364 | Validation metric: 0.9984
# Epoch 098 |loss is: 0.0400 | Validation metric: 0.9974
# Epoch 099 |loss is: 0.0368 | Validation metric: 0.9984
# Epoch 100 |loss is: 0.0354 | Validation metric: 0.9989
# Epoch 101 |loss is: 0.0328 | Validation metric: 0.9982
# Epoch 102 |loss is: 0.0324 | Validation metric: 0.9984
# Epoch 103 |loss is: 0.0373 | Validation metric: 0.9974
# Epoch 104 |loss is: 0.0345 | Validation metric: 0.9964
# Epoch 105 |loss is: 0.0371 | Validation metric: 0.9965
# Epoch 106 |loss is: 0.0345 | Validation metric: 0.9979
# Epoch 107 |loss is: 0.0324 | Validation metric: 0.9948
# Epoch 108 |loss is: 0.0335 | Validation metric: 0.9984
# Epoch 109 |loss is: 0.0361 | Validation metric: 0.9983
# Epoch 110 |loss is: 0.0352 | Validation metric: 0.9979
# Epoch 111 |loss is: 0.0352 | Validation metric: 0.9988
# Epoch 112 |loss is: 0.0480 | Validation metric: 0.9968
# Epoch 113 |loss is: 0.0531 | Validation metric: 0.9983
# Epoch 114 |loss is: 0.0319 | Validation metric: 0.9983
# Epoch 115 |loss is: 0.0389 | Validation metric: 0.9991
# Epoch 116 |loss is: 0.0398 | Validation metric: 0.9971
# Epoch 117 |loss is: 0.0344 | Validation metric: 0.9985
# Epoch 118 |loss is: 0.0312 | Validation metric: 0.9962
# Epoch 119 |loss is: 0.0342 | Validation metric: 0.9974
# Epoch 120 |loss is: 0.0330 | Validation metric: 0.9986
# Epoch 121 |loss is: 0.0351 | Validation metric: 0.9980
# Epoch 122 |loss is: 0.0352 | Validation metric: 0.9987
# Epoch 123 |loss is: 0.0342 | Validation metric: 0.9985
# Epoch 124 |loss is: 0.0302 | Validation metric: 0.9989
# Epoch 125 |loss is: 0.0316 | Validation metric: 0.9988
# Epoch 126 |loss is: 0.0388 | Validation metric: 0.9975
# Epoch 127 |loss is: 0.0392 | Validation metric: 0.9967
# Epoch 128 |loss is: 0.0317 | Validation metric: 0.9988
# Epoch 129 |loss is: 0.0338 | Validation metric: 0.9980
# Epoch 130 |loss is: 0.0379 | Validation metric: 0.9989
# Epoch 131 |loss is: 0.0282 | Validation metric: 0.9973
# Epoch 132 |loss is: 0.0349 | Validation metric: 0.9978
# Epoch 133 |loss is: 0.0327 | Validation metric: 0.9989
# Epoch 134 |loss is: 0.0314 | Validation metric: 0.9993
# Epoch 135 |loss is: 0.0275 | Validation metric: 0.9990
# Epoch 136 |loss is: 0.0314 | Validation metric: 0.9986
# Epoch 137 |loss is: 0.0363 | Validation metric: 0.9978
# Epoch 138 |loss is: 0.0298 | Validation metric: 0.9989
# Epoch 139 |loss is: 0.0327 | Validation metric: 0.9991
# Epoch 140 |loss is: 0.0367 | Validation metric: 0.9985
# Epoch 141 |loss is: 0.0323 | Validation metric: 0.9987
# Epoch 142 |loss is: 0.0371 | Validation metric: 0.9989
# Epoch 143 |loss is: 0.0312 | Validation metric: 0.9957
# Epoch 144 |loss is: 0.0375 | Validation metric: 0.9991
# Epoch 145 |loss is: 0.0251 | Validation metric: 0.9987
# Epoch 146 |loss is: 0.0280 | Validation metric: 0.9993
# Epoch 147 |loss is: 0.0344 | Validation metric: 0.9985
# Epoch 148 |loss is: 0.0306 | Validation metric: 0.9968
# Epoch 149 |loss is: 0.0324 | Validation metric: 0.9987
# Epoch 150 |loss is: 0.0346 | Validation metric: 0.9989
# Epoch 151 |loss is: 0.0267 | Validation metric: 0.9991
# Epoch 152 |loss is: 0.0266 | Validation metric: 0.9991
# Epoch 153 |loss is: 0.0302 | Validation metric: 0.9990
# Epoch 154 |loss is: 0.0294 | Validation metric: 0.9992
# Epoch 155 |loss is: 0.0299 | Validation metric: 0.9987
# Epoch 156 |loss is: 0.0318 | Validation metric: 0.9976
# Epoch 157 |loss is: 0.0316 | Validation metric: 0.9991
# Epoch 158 |loss is: 0.0316 | Validation metric: 0.9977
# Epoch 159 |loss is: 0.0326 | Validation metric: 0.9990
# Epoch 160 |loss is: 0.0289 | Validation metric: 0.9992
# Epoch 161 |loss is: 0.0275 | Validation metric: 0.9977
# Epoch 162 |loss is: 0.0421 | Validation metric: 0.9990
# Epoch 163 |loss is: 0.0287 | Validation metric: 0.9979
# Epoch 164 |loss is: 0.0276 | Validation metric: 0.9994
# Epoch 165 |loss is: 0.0239 | Validation metric: 0.9987
# Epoch 166 |loss is: 0.0299 | Validation metric: 0.9954
# Epoch 167 |loss is: 0.0304 | Validation metric: 0.9989
# Epoch 168 |loss is: 0.0286 | Validation metric: 0.9990
# Epoch 169 |loss is: 0.0337 | Validation metric: 0.9946
# Epoch 170 |loss is: 0.0328 | Validation metric: 0.9989
# Epoch 171 |loss is: 0.0268 | Validation metric: 0.9993
# Epoch 172 |loss is: 0.0330 | Validation metric: 0.9989
# Epoch 173 |loss is: 0.0322 | Validation metric: 0.9991
# Epoch 174 |loss is: 0.0290 | Validation metric: 0.9993
# Epoch 175 |loss is: 0.0244 | Validation metric: 0.9992
# Epoch 176 |loss is: 0.0237 | Validation metric: 0.9991
# Epoch 177 |loss is: 0.0272 | Validation metric: 0.9992
# Epoch 178 |loss is: 0.0304 | Validation metric: 0.9990
# Epoch 179 |loss is: 0.0263 | Validation metric: 0.9992
# Epoch 180 |loss is: 0.0231 | Validation metric: 0.9989
# Epoch 181 |loss is: 0.0293 | Validation metric: 0.9990
# Epoch 182 |loss is: 0.0294 | Validation metric: 0.9994
# Epoch 183 |loss is: 0.0275 | Validation metric: 0.9994
# Epoch 184 |loss is: 0.0290 | Validation metric: 0.9962
# Epoch 185 |loss is: 0.0365 | Validation metric: 0.9991
# Epoch 186 |loss is: 0.0268 | Validation metric: 0.9971
# Epoch 187 |loss is: 0.0257 | Validation metric: 0.9996
# Epoch 188 |loss is: 0.0249 | Validation metric: 0.9992
# Epoch 189 |loss is: 0.0267 | Validation metric: 0.9990
# Epoch 190 |loss is: 0.0266 | Validation metric: 0.9995
# Epoch 191 |loss is: 0.0262 | Validation metric: 0.9986
# Epoch 192 |loss is: 0.0252 | Validation metric: 0.9984
# Epoch 193 |loss is: 0.0253 | Validation metric: 0.9992
# Epoch 194 |loss is: 0.0281 | Validation metric: 0.9986
# Epoch 195 |loss is: 0.0318 | Validation metric: 0.9979
# Epoch 196 |loss is: 0.0252 | Validation metric: 0.9991
# Epoch 197 |loss is: 0.0276 | Validation metric: 0.9996
# Epoch 198 |loss is: 0.0245 | Validation metric: 0.9995
# Epoch 199 |loss is: 0.0268 | Validation metric: 0.9995
# Epoch 200 |loss is: 0.0235 | Validation metric: 0.9995
# Epoch 201 |loss is: 0.0341 | Validation metric: 0.9990
# Epoch 202 |loss is: 0.0377 | Validation metric: 0.9990
# Epoch 203 |loss is: 0.0320 | Validation metric: 0.9992
# Epoch 204 |loss is: 0.0279 | Validation metric: 0.9995
# Epoch 205 |loss is: 0.0244 | Validation metric: 0.9989
# Epoch 206 |loss is: 0.0251 | Validation metric: 0.9995
# Epoch 207 |loss is: 0.0253 | Validation metric: 0.9993
# Epoch 208 |loss is: 0.0282 | Validation metric: 0.9981
# Epoch 209 |loss is: 0.0264 | Validation metric: 0.9993
# Epoch 210 |loss is: 0.0273 | Validation metric: 0.9956
# Epoch 211 |loss is: 0.0271 | Validation metric: 0.9985
# Epoch 212 |loss is: 0.0243 | Validation metric: 0.9991
# Epoch 213 |loss is: 0.0225 | Validation metric: 0.9992
# Epoch 214 |loss is: 0.0226 | Validation metric: 0.9989
# Epoch 215 |loss is: 0.0228 | Validation metric: 0.9995
# Epoch 216 |loss is: 0.0292 | Validation metric: 0.9991
# Epoch 217 |loss is: 0.0261 | Validation metric: 0.9995
# Epoch 218 |loss is: 0.0249 | Validation metric: 0.9993
# Epoch 219 |loss is: 0.0270 | Validation metric: 0.9994
# Epoch 220 |loss is: 0.0239 | Validation metric: 0.9993
# Epoch 221 |loss is: 0.0270 | Validation metric: 0.9994
# Epoch 222 |loss is: 0.0239 | Validation metric: 0.9994
# Epoch 223 |loss is: 0.0256 | Validation metric: 0.9991
# Epoch 224 |loss is: 0.0282 | Validation metric: 0.9995
# Epoch 225 |loss is: 0.0265 | Validation metric: 0.9990
# Epoch 226 |loss is: 0.0278 | Validation metric: 0.9995
# Epoch 227 |loss is: 0.0257 | Validation metric: 0.9991
# Epoch 228 |loss is: 0.0213 | Validation metric: 0.9992
# Epoch 229 |loss is: 0.0234 | Validation metric: 0.9993
# Epoch 230 |loss is: 0.0261 | Validation metric: 0.9991
# Epoch 231 |loss is: 0.0267 | Validation metric: 0.9993
# Epoch 232 |loss is: 0.0204 | Validation metric: 0.9994
# Epoch 233 |loss is: 0.0240 | Validation metric: 0.9989
# Epoch 234 |loss is: 0.0214 | Validation metric: 0.9987
# Epoch 235 |loss is: 0.0252 | Validation metric: 0.9991
# Epoch 236 |loss is: 0.0277 | Validation metric: 0.9995
# Epoch 237 |loss is: 0.0225 | Validation metric: 0.9990
# Epoch 238 |loss is: 0.0236 | Validation metric: 0.9995
# Epoch 239 |loss is: 0.0248 | Validation metric: 0.9995
# Epoch 240 |loss is: 0.0200 | Validation metric: 0.9996
# Epoch 241 |loss is: 0.0243 | Validation metric: 0.9995
# Epoch 242 |loss is: 0.0267 | Validation metric: 0.9996
# Epoch 243 |loss is: 0.0301 | Validation metric: 0.9989
# Epoch 244 |loss is: 0.0214 | Validation metric: 0.9997
# Epoch 245 |loss is: 0.0209 | Validation metric: 0.9994
# Epoch 246 |loss is: 0.0245 | Validation metric: 0.9984
# Epoch 247 |loss is: 0.0265 | Validation metric: 0.9982
# Epoch 248 |loss is: 0.0222 | Validation metric: 0.9995
# Epoch 249 |loss is: 0.0289 | Validation metric: 0.9995
# Epoch 250 |loss is: 0.0305 | Validation metric: 0.9987
# Epoch 251 |loss is: 0.0202 | Validation metric: 0.9994
# Epoch 252 |loss is: 0.0198 | Validation metric: 0.9994
# Epoch 253 |loss is: 0.0238 | Validation metric: 0.9993
# Epoch 254 |loss is: 0.0259 | Validation metric: 0.9996
# Epoch 255 |loss is: 0.0216 | Validation metric: 0.9997
# Epoch 256 |loss is: 0.0229 | Validation metric: 0.9996
# Epoch 257 |loss is: 0.0207 | Validation metric: 0.9994
# Epoch 258 |loss is: 0.0231 | Validation metric: 0.9989
# Epoch 259 |loss is: 0.0238 | Validation metric: 0.9995
# Epoch 260 |loss is: 0.0186 | Validation metric: 0.9995
# Epoch 261 |loss is: 0.0234 | Validation metric: 0.9996
# Epoch 262 |loss is: 0.0317 | Validation metric: 0.9993
# Epoch 263 |loss is: 0.0211 | Validation metric: 0.9993
# Epoch 264 |loss is: 0.0214 | Validation metric: 0.9993
# Epoch 265 |loss is: 0.0229 | Validation metric: 0.9995
# Epoch 266 |loss is: 0.0239 | Validation metric: 0.9995
# Epoch 267 |loss is: 0.0221 | Validation metric: 0.9995
# Epoch 268 |loss is: 0.0208 | Validation metric: 0.9992
# Epoch 269 |loss is: 0.0227 | Validation metric: 0.9997
# Epoch 270 |loss is: 0.0235 | Validation metric: 0.9980
# Epoch 271 |loss is: 0.0241 | Validation metric: 0.9994
# Epoch 272 |loss is: 0.0192 | Validation metric: 0.9993
# Epoch 273 |loss is: 0.0222 | Validation metric: 0.9994
# Epoch 274 |loss is: 0.0197 | Validation metric: 0.9995
# Epoch 275 |loss is: 0.0242 | Validation metric: 0.9995
# Epoch 276 |loss is: 0.0283 | Validation metric: 0.9993
# Epoch 277 |loss is: 0.0233 | Validation metric: 0.9995
# Epoch 278 |loss is: 0.0174 | Validation metric: 0.9996
# Epoch 279 |loss is: 0.0203 | Validation metric: 0.9995
# Epoch 280 |loss is: 0.0243 | Validation metric: 0.9995
# Epoch 281 |loss is: 0.0195 | Validation metric: 0.9996
# Epoch 282 |loss is: 0.0198 | Validation metric: 0.9996
# Epoch 283 |loss is: 0.0226 | Validation metric: 0.9994
# Epoch 284 |loss is: 0.0211 | Validation metric: 0.9997
# Epoch 285 |loss is: 0.0181 | Validation metric: 0.9998
# Epoch 286 |loss is: 0.0190 | Validation metric: 0.9996
# Epoch 287 |loss is: 0.0217 | Validation metric: 0.9993
# Epoch 288 |loss is: 0.0207 | Validation metric: 0.9996
# Epoch 289 |loss is: 0.0227 | Validation metric: 0.9996
# Epoch 290 |loss is: 0.0198 | Validation metric: 0.9997
# Epoch 291 |loss is: 0.0193 | Validation metric: 0.9997
# Epoch 292 |loss is: 0.0231 | Validation metric: 0.9993
# Epoch 293 |loss is: 0.0220 | Validation metric: 0.9997
# Epoch 294 |loss is: 0.0217 | Validation metric: 0.9997
# Epoch 295 |loss is: 0.0189 | Validation metric: 0.9998
# Epoch 296 |loss is: 0.0200 | Validation metric: 0.9996
# Epoch 297 |loss is: 0.0186 | Validation metric: 0.9996
# Epoch 298 |loss is: 0.0248 | Validation metric: 0.9996
# Epoch 299 |loss is: 0.0261 | Validation metric: 0.9997
# Epoch 300 |loss is: 0.0207 | Validation metric: 0.9995
# Epoch 301 |loss is: 0.0213 | Validation metric: 0.9996
# Epoch 302 |loss is: 0.0187 | Validation metric: 0.9996
# Epoch 303 |loss is: 0.0181 | Validation metric: 0.9994
# Epoch 304 |loss is: 0.0195 | Validation metric: 0.9997
# Epoch 305 |loss is: 0.0207 | Validation metric: 0.9998
# Epoch 306 |loss is: 0.0185 | Validation metric: 0.9992
# Epoch 307 |loss is: 0.0202 | Validation metric: 0.9998
# Epoch 308 |loss is: 0.0230 | Validation metric: 0.9992
# Epoch 309 |loss is: 0.0185 | Validation metric: 0.9997
# Epoch 310 |loss is: 0.0171 | Validation metric: 0.9989
# Epoch 311 |loss is: 0.0216 | Validation metric: 0.9998
# Epoch 312 |loss is: 0.0196 | Validation metric: 0.9991
# Epoch 313 |loss is: 0.0235 | Validation metric: 0.9997
# Epoch 314 |loss is: 0.0200 | Validation metric: 0.9992
# Epoch 315 |loss is: 0.0199 | Validation metric: 0.9997
# Epoch 316 |loss is: 0.0255 | Validation metric: 0.9997
# Epoch 317 |loss is: 0.0195 | Validation metric: 0.9997
# Epoch 318 |loss is: 0.0204 | Validation metric: 0.9997
# Epoch 319 |loss is: 0.0205 | Validation metric: 0.9992
# Epoch 320 |loss is: 0.0191 | Validation metric: 0.9994
# Epoch 321 |loss is: 0.0230 | Validation metric: 0.9991
# Epoch 322 |loss is: 0.0246 | Validation metric: 0.9998
# Epoch 323 |loss is: 0.0200 | Validation metric: 0.9994
# Epoch 324 |loss is: 0.0188 | Validation metric: 0.9998
# Epoch 325 |loss is: 0.0185 | Validation metric: 0.9994
# Epoch 326 |loss is: 0.0178 | Validation metric: 0.9992
# Epoch 327 |loss is: 0.0192 | Validation metric: 0.9998
# Epoch 328 |loss is: 0.0196 | Validation metric: 0.9998
# Epoch 329 |loss is: 0.0178 | Validation metric: 0.9995
# Epoch 330 |loss is: 0.0184 | Validation metric: 0.9998
# Epoch 331 |loss is: 0.0223 | Validation metric: 0.9997
# Epoch 332 |loss is: 0.0184 | Validation metric: 0.9970
# Epoch 333 |loss is: 0.0243 | Validation metric: 0.9998
# Epoch 334 |loss is: 0.0218 | Validation metric: 0.9994
# Epoch 335 |loss is: 0.0190 | Validation metric: 0.9997
# Epoch 336 |loss is: 0.0164 | Validation metric: 0.9995
# Epoch 337 |loss is: 0.0163 | Validation metric: 0.9994
# Epoch 338 |loss is: 0.0190 | Validation metric: 0.9998
# Epoch 339 |loss is: 0.0176 | Validation metric: 0.9998
# Epoch 340 |loss is: 0.0215 | Validation metric: 0.9994
# Epoch 341 |loss is: 0.0188 | Validation metric: 0.9997
# Epoch 342 |loss is: 0.0202 | Validation metric: 0.9997
# Epoch 343 |loss is: 0.0180 | Validation metric: 0.9998
# Epoch 344 |loss is: 0.0187 | Validation metric: 0.9998
# Epoch 345 |loss is: 0.0209 | Validation metric: 0.9997
# Epoch 346 |loss is: 0.0223 | Validation metric: 0.9995
# Epoch 347 |loss is: 0.0201 | Validation metric: 0.9997
# Epoch 348 |loss is: 0.0231 | Validation metric: 0.9997
# Epoch 349 |loss is: 0.0208 | Validation metric: 0.9997
# Epoch 350 |loss is: 0.0203 | Validation metric: 0.9998
# Epoch 351 |loss is: 0.0190 | Validation metric: 0.9997
# Epoch 352 |loss is: 0.0174 | Validation metric: 0.9997
# Epoch 353 |loss is: 0.0202 | Validation metric: 0.9997
# Epoch 354 |loss is: 0.0270 | Validation metric: 0.9998
# Epoch 355 |loss is: 0.0229 | Validation metric: 0.9997
# Epoch 356 |loss is: 0.0241 | Validation metric: 0.9997
# Epoch 357 |loss is: 0.0204 | Validation metric: 0.9997
# Epoch 358 |loss is: 0.0197 | Validation metric: 0.9994
# Epoch 359 |loss is: 0.0201 | Validation metric: 0.9998
# Epoch 360 |loss is: 0.0137 | Validation metric: 0.9998
# Epoch 361 |loss is: 0.0169 | Validation metric: 0.9991
# Epoch 362 |loss is: 0.0254 | Validation metric: 0.9997
# Epoch 363 |loss is: 0.0241 | Validation metric: 0.9994
# Epoch 364 |loss is: 0.0243 | Validation metric: 0.9996
# Epoch 365 |loss is: 0.0158 | Validation metric: 0.9997
# Epoch 366 |loss is: 0.0213 | Validation metric: 0.9998
# Epoch 367 |loss is: 0.0386 | Validation metric: 0.9980
# Epoch 368 |loss is: 0.0208 | Validation metric: 0.9996
# Epoch 369 |loss is: 0.0216 | Validation metric: 0.9997
# Epoch 370 |loss is: 0.0181 | Validation metric: 0.9997
# Epoch 371 |loss is: 0.0204 | Validation metric: 0.9995
# Epoch 372 |loss is: 0.0152 | Validation metric: 0.9997
# Epoch 373 |loss is: 0.0174 | Validation metric: 0.9998
# Epoch 374 |loss is: 0.0192 | Validation metric: 0.9996
# Epoch 375 |loss is: 0.0194 | Validation metric: 0.9998
# Epoch 376 |loss is: 0.0162 | Validation metric: 0.9996
# Epoch 377 |loss is: 0.0169 | Validation metric: 0.9996
# Epoch 378 |loss is: 0.0191 | Validation metric: 0.9995
# Epoch 379 |loss is: 0.0166 | Validation metric: 0.9997
# Epoch 380 |loss is: 0.0202 | Validation metric: 0.9998
# Epoch 381 |loss is: 0.0177 | Validation metric: 0.9997
# Epoch 382 |loss is: 0.0315 | Validation metric: 0.9997
# Epoch 383 |loss is: 0.0189 | Validation metric: 0.9996
# Epoch 384 |loss is: 0.0171 | Validation metric: 0.9996
# Epoch 385 |loss is: 0.0162 | Validation metric: 0.9997
# Epoch 386 |loss is: 0.0202 | Validation metric: 0.9995
# Epoch 387 |loss is: 0.0172 | Validation metric: 0.9997
# Epoch 388 |loss is: 0.0218 | Validation metric: 0.9997
# Epoch 389 |loss is: 0.0222 | Validation metric: 0.9997
# Epoch 390 |loss is: 0.0212 | Validation metric: 0.9998
# Epoch 391 |loss is: 0.0213 | Validation metric: 0.9991
# Epoch 392 |loss is: 0.0186 | Validation metric: 0.9997
# Epoch 393 |loss is: 0.0165 | Validation metric: 0.9998
# Epoch 394 |loss is: 0.0162 | Validation metric: 0.9996
# Epoch 395 |loss is: 0.0190 | Validation metric: 0.9992
# Epoch 396 |loss is: 0.0157 | Validation metric: 0.9995
# Epoch 397 |loss is: 0.0174 | Validation metric: 0.9998
# Epoch 398 |loss is: 0.0183 | Validation metric: 0.9997
# Epoch 399 |loss is: 0.0201 | Validation metric: 0.9997
# Epoch 400 |loss is: 0.0185 | Validation metric: 0.9998
# Epoch 401 |loss is: 0.0176 | Validation metric: 0.9998
# Epoch 402 |loss is: 0.0176 | Validation metric: 0.9998
# Epoch 403 |loss is: 0.0227 | Validation metric: 0.9998
# Epoch 404 |loss is: 0.0172 | Validation metric: 0.9991
# Epoch 405 |loss is: 0.0171 | Validation metric: 0.9997
# Epoch 406 |loss is: 0.0178 | Validation metric: 0.9996
# Epoch 407 |loss is: 0.0177 | Validation metric: 0.9998
# Epoch 408 |loss is: 0.0206 | Validation metric: 0.9996
# Epoch 409 |loss is: 0.0241 | Validation metric: 0.9997
# Epoch 410 |loss is: 0.0199 | Validation metric: 0.9998
# Epoch 411 |loss is: 0.0202 | Validation metric: 0.9996
# Epoch 412 |loss is: 0.0183 | Validation metric: 0.9997
# Epoch 413 |loss is: 0.0197 | Validation metric: 0.9998
# Epoch 414 |loss is: 0.0203 | Validation metric: 0.9998
# Epoch 415 |loss is: 0.0194 | Validation metric: 0.9998
# Epoch 416 |loss is: 0.0170 | Validation metric: 0.9998
# Epoch 417 |loss is: 0.0173 | Validation metric: 0.9998
# Epoch 418 |loss is: 0.0204 | Validation metric: 0.9999
# Epoch 419 |loss is: 0.0197 | Validation metric: 0.9994
# Epoch 420 |loss is: 0.0191 | Validation metric: 0.9998
# Epoch 421 |loss is: 0.0167 | Validation metric: 0.9996
# Epoch 422 |loss is: 0.0139 | Validation metric: 0.9999
# Epoch 423 |loss is: 0.0167 | Validation metric: 0.9996
# Epoch 424 |loss is: 0.0209 | Validation metric: 0.9992
# Epoch 425 |loss is: 0.0272 | Validation metric: 0.9998
# Epoch 426 |loss is: 0.0144 | Validation metric: 0.9998
# Epoch 427 |loss is: 0.0174 | Validation metric: 0.9997
# Epoch 428 |loss is: 0.0222 | Validation metric: 0.9997
# Epoch 429 |loss is: 0.0199 | Validation metric: 0.9998
# Epoch 430 |loss is: 0.0143 | Validation metric: 0.9998
# Epoch 431 |loss is: 0.0146 | Validation metric: 0.9997
# Epoch 432 |loss is: 0.0162 | Validation metric: 0.9996
# Epoch 433 |loss is: 0.0185 | Validation metric: 0.9998
# Epoch 434 |loss is: 0.0155 | Validation metric: 0.9995
# Epoch 435 |loss is: 0.0185 | Validation metric: 0.9998
# Epoch 436 |loss is: 0.0172 | Validation metric: 0.9998
# Epoch 437 |loss is: 0.0183 | Validation metric: 0.9997
# Epoch 438 |loss is: 0.0176 | Validation metric: 0.9998
# Epoch 439 |loss is: 0.0183 | Validation metric: 0.9998
# Epoch 440 |loss is: 0.0146 | Validation metric: 0.9998
# Epoch 441 |loss is: 0.0170 | Validation metric: 0.9998
# Epoch 442 |loss is: 0.0191 | Validation metric: 0.9998
# Epoch 443 |loss is: 0.0149 | Validation metric: 0.9999
# Epoch 444 |loss is: 0.0139 | Validation metric: 0.9998
# Epoch 445 |loss is: 0.0181 | Validation metric: 0.9997
# Epoch 446 |loss is: 0.0183 | Validation metric: 0.9997
# Epoch 447 |loss is: 0.0186 | Validation metric: 0.9998
# Epoch 448 |loss is: 0.0146 | Validation metric: 0.9997
# Epoch 449 |loss is: 0.0270 | Validation metric: 0.9997
# Epoch 450 |loss is: 0.0213 | Validation metric: 0.9998
# Epoch 451 |loss is: 0.0285 | Validation metric: 0.9997
# Epoch 452 |loss is: 0.0167 | Validation metric: 0.9998
# Epoch 453 |loss is: 0.0143 | Validation metric: 0.9997
# Epoch 454 |loss is: 0.0179 | Validation metric: 0.9998
# Epoch 455 |loss is: 0.0161 | Validation metric: 0.9999
# Epoch 456 |loss is: 0.0143 | Validation metric: 0.9997
# Epoch 457 |loss is: 0.0186 | Validation metric: 0.9999
# Epoch 458 |loss is: 0.0230 | Validation metric: 0.9996
# Epoch 459 |loss is: 0.0166 | Validation metric: 0.9998
# Epoch 460 |loss is: 0.0188 | Validation metric: 0.9997
# Epoch 461 |loss is: 0.0181 | Validation metric: 0.9999
# Epoch 462 |loss is: 0.0178 | Validation metric: 0.9999
# Epoch 463 |loss is: 0.0153 | Validation metric: 0.9999
# Epoch 464 |loss is: 0.0158 | Validation metric: 0.9993
# Epoch 465 |loss is: 0.0173 | Validation metric: 0.9999
# Epoch 466 |loss is: 0.0174 | Validation metric: 0.9999
# Epoch 467 |loss is: 0.0181 | Validation metric: 0.9996
# Epoch 468 |loss is: 0.0184 | Validation metric: 0.9997
# Epoch 469 |loss is: 0.0163 | Validation metric: 0.9998
# Epoch 470 |loss is: 0.0154 | Validation metric: 0.9999
# Epoch 471 |loss is: 0.0165 | Validation metric: 0.9998
# Epoch 472 |loss is: 0.0219 | Validation metric: 0.9997
# Epoch 473 |loss is: 0.0183 | Validation metric: 0.9998
# Epoch 474 |loss is: 0.0193 | Validation metric: 0.9998
# Epoch 475 |loss is: 0.0154 | Validation metric: 0.9998
# Epoch 476 |loss is: 0.0227 | Validation metric: 0.9998
# Epoch 477 |loss is: 0.0156 | Validation metric: 0.9999
# Epoch 478 |loss is: 0.0168 | Validation metric: 0.9998
# Epoch 479 |loss is: 0.0152 | Validation metric: 0.9998
# Epoch 480 |loss is: 0.0154 | Validation metric: 0.9997
# Epoch 481 |loss is: 0.0152 | Validation metric: 0.9998
# Epoch 482 |loss is: 0.0154 | Validation metric: 0.9999
# Epoch 483 |loss is: 0.0154 | Validation metric: 0.9998
# Epoch 484 |loss is: 0.0137 | Validation metric: 0.9999
# Epoch 485 |loss is: 0.0141 | Validation metric: 0.9996
# Epoch 486 |loss is: 0.0184 | Validation metric: 0.9997
# Epoch 487 |loss is: 0.0185 | Validation metric: 0.9998
# Epoch 488 |loss is: 0.0176 | Validation metric: 0.9999
# Epoch 489 |loss is: 0.0176 | Validation metric: 0.9999
# Epoch 490 |loss is: 0.0143 | Validation metric: 0.9998
# Epoch 491 |loss is: 0.0164 | Validation metric: 0.9998
# Epoch 492 |loss is: 0.0164 | Validation metric: 0.9996
# Epoch 493 |loss is: 0.0224 | Validation metric: 0.9996
# Epoch 494 |loss is: 0.0188 | Validation metric: 0.9996
# Epoch 495 |loss is: 0.0222 | Validation metric: 0.9998
# Epoch 496 |loss is: 0.0202 | Validation metric: 0.9994
# Epoch 497 |loss is: 0.0144 | Validation metric: 0.9998
# Epoch 498 |loss is: 0.0159 | Validation metric: 0.9997
# Epoch 499 |loss is: 0.0177 | Validation metric: 0.9999
# Epoch 500 |loss is: 0.0155 | Validation metric: 0.9998
# Epoch 501 |loss is: 0.0167 | Validation metric: 0.9996
# Epoch 502 |loss is: 0.0150 | Validation metric: 0.9998
# Epoch 503 |loss is: 0.0159 | Validation metric: 0.9999
# Epoch 504 |loss is: 0.0139 | Validation metric: 0.9998
# Epoch 505 |loss is: 0.0167 | Validation metric: 0.9998
# Epoch 506 |loss is: 0.0142 | Validation metric: 0.9998
# Epoch 507 |loss is: 0.0144 | Validation metric: 0.9997
# Epoch 508 |loss is: 0.0164 | Validation metric: 0.9999
# Epoch 509 |loss is: 0.0191 | Validation metric: 0.9998
# Epoch 510 |loss is: 0.0185 | Validation metric: 0.9997
# Epoch 511 |loss is: 0.0189 | Validation metric: 0.9999
# Epoch 512 |loss is: 0.0174 | Validation metric: 0.9997
# Epoch 513 |loss is: 0.0146 | Validation metric: 0.9998
# Epoch 514 |loss is: 0.0157 | Validation metric: 0.9998
# Epoch 515 |loss is: 0.0137 | Validation metric: 0.9999
# Epoch 516 |loss is: 0.0188 | Validation metric: 0.9998
# Epoch 517 |loss is: 0.0161 | Validation metric: 0.9996
# Epoch 518 |loss is: 0.0135 | Validation metric: 0.9998
# Epoch 519 |loss is: 0.0157 | Validation metric: 0.9999
# Epoch 520 |loss is: 0.0192 | Validation metric: 0.9999
# Epoch 521 |loss is: 0.0168 | Validation metric: 0.9998
# Epoch 522 |loss is: 0.0157 | Validation metric: 0.9998
# Epoch 523 |loss is: 0.0137 | Validation metric: 0.9995
# Epoch 524 |loss is: 0.0133 | Validation metric: 0.9999
# Epoch 525 |loss is: 0.0151 | Validation metric: 0.9999
# Epoch 526 |loss is: 0.0173 | Validation metric: 0.9997
# Epoch 527 |loss is: 0.0188 | Validation metric: 0.9992
# Epoch 528 |loss is: 0.0237 | Validation metric: 0.9999
# Epoch 529 |loss is: 0.0174 | Validation metric: 0.9999
# Epoch 530 |loss is: 0.0243 | Validation metric: 0.9997
# Epoch 531 |loss is: 0.0331 | Validation metric: 0.9998

# %% [markdown]
# ### 7.loss曲线，测试集验证

# %%
from matplotlib import pyplot as plt
plt.plot(train_loss)
plt.plot(eval_loss)
plt.show()

# %%
# metric
def metric(y_test=None,y_score=None):
    aucroc = roc_auc_score(y_true=y_test, y_score=y_score)
    aucpr = average_precision_score(y_true=y_test, y_score=y_score, pos_label=1)
    metric = {'aucroc': aucroc, 'aucpr': aucpr}
    return metric
y_val_scores = scipy.special.expit(model(paddle.to_tensor(X_test,dtype="float32")).numpy())
metric(y_test=y_test, y_score=y_val_scores)
# 保存模型
paddle.save(model.state_dict(), "model.pdparams")

# %% [markdown]
# ### 8.生成提交文件

# %%
import paddle
import platform

model = ResNet.make_baseline(
                d_in=8,
                d_main=128,
                d_hidden=256,
                dropout_first=0.25,
                dropout_second=0.0,
                n_blocks=2,
                d_out=1,
            )
param_dict = paddle.load("model.pdparams")
model.load_dict(param_dict)
model.eval()
y_val_scores = scipy.special.expit(model(paddle.to_tensor(X_val,dtype="float32")).numpy())
#y_val_scores = clf.predict_score(X_val)   #返回未知数据上的异常值 (分值越大越异常) # outlier scores
#记录文件名和对应的异常得分
predict_result={}
for i in tqdm(range(len(test1_files))):
    file=test1_files[i]
    #如果是window系统：
    if platform.system().lower() == 'windows':
        name=file.split('\\')[-1]
    #如果是linux系统
    elif platform.system().lower() == 'linux':
        name=file.split('/')[-1]
    predict_result[name]=y_val_scores[i].item()
predict_score=pd.DataFrame(list(predict_result.items()),columns=['file_name','score'])#列名必须为这俩个
predict_score.to_csv(f'submision.csv',index = False) #保存为比赛要求的csv文件
# Out:
# 100%|██████████| 6234/6234 [00:00<00:00, 512470.92it/s]
